# %%
#importing necessary packages
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
#Defining the function
def data():
  ds=pd.read_csv("//content//AIS.csv") #Please change the location of the AIS.csv file
  ds=ds.dropna()
  Training_input_set=ds[['LAT','LON']]
  Training_output_set=ds['Reason']
  classifier=DecisionTreeClassifier()
  classifier.fit(Training_input_set.values,Training_output_set)
  lat=float(input("Enter Latitiude:"))
  lon=float(input("Enter Longitude:"))
  print(classifier.predict([[lat,lon]])[0])
#Checking status of AIS
ais=input("Enter active or inactive : ")
i=0
#Condition for function call
if ais=="inactive":
    i=1
    while(i==1):
        data()
        i=int(input("Enter 1 to run again or any other number to exit : "))
else:
    print("AIS is active")
# Out:
# Enter active or inactive : ACTIVE
# AIS is active

# %%
#importing necessary packages
import pandas as pd
from datetime import date
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
#Defining the function
def data():
  ds=pd.read_csv("//content//AIS_2.csv") #Please change the location of the AIS.csv file
  ds=ds.dropna()
  print(ds.head())
  print(ds.filter(["reason"]))
  data = ds.filter(["LAT","LON"])
  label=ds.filter(["reason"])
  x_train, x_test, y_train, y_test= train_test_split(data, label, test_size= 0.25, random_state=0)
  classifier=DecisionTreeClassifier()
  classifier.fit(x_train,y_train)
  date_components = input('Enter a date formatted as YYYY/MM/DD: ')
  vesslename=input("Enter the vessel name:")
  LAT=float(input("Enter Latitiude:"))
  LON=float(input("Enter Longitude:"))
  val = classifier.predict(x_test)
  print(val[0])
#Checking status of AIS
ais=input("Enter active or inactive : ")
i=0
#Condition for function call
if ais=="inactive":
    i=1
    while(i==1):
        data()
        i=int(input("Enter 1 to run again or any other number to exit : "))
else:
    print("AIS is active")
# Out:
# Enter active or inactive : inactive
# Enter a date formatted as YYYY/MM/DD: 2022/02/05
# Enter the vessel name:BLUE
# Enter Latitiude:50
# Enter Longitude:90
# Entering countyy's without permission
# Enter 1 to run again or any other number to exit : 0

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
df=pd.read_csv("/content/AIS_2.csv")
df
df.columns
x=df.drop(columns=df.columns[2:])
y=df[df.columns[2:4]]
model=DecisionTreeClassifier()
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
df['reason']=encode.fit_transform(df['reason'])
model.fit(y,df['reason'])
date=input("Enter Date")
time=input("Enter Time")
a=df[df.eq(date).any(1)]
print('LAT-',a[" LAT"].item(),'LON-',a["LON"].item())
LAT =float(input("Enter lattitude"))
LON=float(input("Enter longitude"))
model.predict([[a[' LAT'].item(),a["LON"].item()]])[0]
Pred=model.predict([[a[" LAT"].item(),a['LON'].item()]])[0]
if Pred==0:
    print("entering country's without permission")
elif Pred==1:
    print("illegal drug smuggling")
elif Pred==2:
    print("illegal fishing")
elif Pred==3:
    print("low frequency region")
elif Pred==4:
    print("poor ais device")
else:
    print("NAN")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-036cb8e5d402> in <cell line: 3>()
#       1 import pandas as pd
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 3 df=pd.read_csv("/content/AIS_2.csv")
#       4 df
#       5 df.columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
import pandas as pd

# %%
pd.head()
